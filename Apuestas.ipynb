LaLiga_2016_2017='https://raw.githubusercontent.com/450fausto/database/main/LaLiga_2016_2017.csv'
LaLiga_2017_2018='https://raw.githubusercontent.com/450fausto/database/main/LaLiga_2017_2018.csv'
LaLiga_2018_2019='https://raw.githubusercontent.com/450fausto/database/main/LaLiga_2018_2019.csv'

SerieA_2013_2014='https://raw.githubusercontent.com/450fausto/database/main/SerieA_2013_2014.csv'
SerieA_2014_2015='https://raw.githubusercontent.com/450fausto/database/main/SerieA_2014_2015.csv'
SerieA_2015_2016='https://raw.githubusercontent.com/450fausto/database/main/SerieA_2015_2016.csv'
SerieA_2016_2017='https://raw.githubusercontent.com/450fausto/database/main/SerieA_2016_2017.csv'
SerieA_2017_2018='https://raw.githubusercontent.com/450fausto/database/main/SerieA_2017_2018.csv'
SerieA_2018_2019='https://raw.githubusercontent.com/450fausto/database/main/SerieA_2018_2019.csv'

Ligue1_2013_2014='https://raw.githubusercontent.com/450fausto/database/main/Ligue1_2013_2014.csv'
Ligue1_2014_2015='https://raw.githubusercontent.com/450fausto/database/main/Ligue1_2014_2015.csv'
Ligue1_2015_2016='https://raw.githubusercontent.com/450fausto/database/main/Ligue1_2015_2016.csv'
Ligue1_2016_2017='https://raw.githubusercontent.com/450fausto/database/main/Ligue1_2016_2017.csv'
Ligue1_2017_2018='https://raw.githubusercontent.com/450fausto/database/main/Ligue1_2017_2018.csv'
Ligue1_2018_2019='https://raw.githubusercontent.com/450fausto/database/main/Ligue1_2018_2019.csv'

Premier_League='https://raw.githubusercontent.com/450fausto/database/main/E0%20(10).csv'    # Crystal Palace	Leeds	0	0 50%
Scotland='https://raw.githubusercontent.com/450fausto/database/main/SC0%20(10).csv'  #   St Mirren	Rangers	0	4 Se acabó la liga
Bundesliga='https://raw.githubusercontent.com/450fausto/database/main/D1%20(4).csv'   #  Hertha	Stuttgart	2	0 50%
Serie_A='https://raw.githubusercontent.com/450fausto/database/main/I1%20(2).csv'      #  Sassuolo	Juventus	1	2  55%        
LaLiga='https://raw.githubusercontent.com/450fausto/database/main/SP1%20(9).csv'     #  Barcelona	Vallecano	0	1 55 %
Ligue1='https://raw.githubusercontent.com/450fausto/database/main/F1%20(8).csv'      #  Brest	Lyon	2	1 45%
Eredivisie='https://raw.githubusercontent.com/450fausto/database/main/N1%20(9).csv'   #  For Sittard	Go Ahead Eagles	1	0 55%
Primeira_Liga='https://raw.githubusercontent.com/450fausto/database/main/P1.csv'      #  Estoril	Sp Braga	0	0 55%


Aa=pd.read_csv(Eredivisie)

# %%
Aa
# Out:
#     Div        Date   Time         HomeTeam         AwayTeam  FTHG  FTAG FTR  \
# 0    N1  13/08/2021  19:00  Go Ahead Eagles       Heerenveen     0     1   A
# 1    N1  14/08/2021  15:30         Waalwijk       AZ Alkmaar     1     0   H
# 2    N1  14/08/2021  17:45         Heracles    PSV Eindhoven     0     2   A
# 3    N1  14/08/2021  19:00      For Sittard           Twente     2     1   H
# 4    N1  14/08/2021  20:00             Ajax         Nijmegen     5     0   H
# ..   ..         ...    ...              ...              ...   ...   ...  ..
# 265  N1  23/04/2022  20:00          Cambuur    PSV Eindhoven     1     2   A
# 266  N1  24/04/2022  11:15        Willem II          Vitesse     1     0   H
# 267  N1  24/04/2022  13:30        Feyenoord          Utrecht     2     1   H
# 268  N1  24/04/2022  13:30        Groningen         Heracles     0     1   A
# 269  N1  24/04/2022  15:45      For Sittard  Go Ahead Eagles     1     0   H
#
# ...

# %%
equipo_local=Aa.HomeTeam
equipo_visitante=Aa.AwayTeam
marcador_local=Aa.FTHG
marcador_visitante=Aa.FTAG
momio_local=Aa.B365H
momio_visitante=Aa.B365A
Puntos=pd.DataFrame({'puntos':1000*np.ones(Aa.HomeTeam.unique().size)}, index=Aa.HomeTeam.unique())
n_media_movil=2*Aa.HomeTeam.unique().size
media_movil=[]


aument_predice=[]
aument_acierta=[]
aument_apuesta=[]
no_partido_apuesta=[]
gana_apuesta=[]
no_partido=[]
momios_guardados=[]

####################################################
# Criterios para realizar la apuesta

criterio=8  # diferencia entre equipos
momio_minimo=2
PJ=0       # Número de partidos jugados
EM_min=0.6     # valor mínimo de la media móvil
####################################################

for i in range(equipo_local.size):

  name_local=equipo_local[i]
  name_visitante=equipo_visitante[i]
  resultado=marcador_local[i]-marcador_visitante[i]

  winner_real='bla-bla'

  if resultado>0:
    winner_real=name_local
    
  elif resultado<0:
    winner_real=name_visitante
    

  if (Puntos.loc[name_local]>Puntos.loc[name_visitante]).bool():
    winner_esperado=name_local
    momio=momio_local[i]
  else:
    winner_esperado=name_visitante
    momio=momio_visitante[i]

  Predecir=np.abs(Puntos.loc[name_local]-Puntos.loc[name_visitante])>criterio
  Predecir=Predecir.bool()

  if Predecir:
    aument_predice.append(1)
    no_partido.append(i)
    aument_acierta.append(winner_real==winner_esperado)
    media_movil.append(sum(aument_acierta[-n_media_movil:])/n_media_movil)

  Apostar=Predecir and i>PJ and media_movil[-1]>=EM_min and momio>momio_minimo

  if Apostar:
    aument_apuesta.append(1)
    no_partido_apuesta.append(i)
    gana_apuesta.append(winner_real==winner_esperado)
    if winner_real==winner_esperado:
      momios_guardados.append(momio)
  

  
  ########################################################################
  # Bloque borrable, no altera el código
  #######################################################
  if i==0:
    Cuenta_init=250
    Cuenta=Cuenta_init
  Monto_por_apuesta=0.1*Cuenta_init
  if Apostar:
    Cuenta+=-Monto_por_apuesta
    if winner_real==winner_esperado:
      Cuenta+=Monto_por_apuesta*momio
  if Cuenta<0:
    print('------------------------------Cuenta rota-----------------------------')
      
  #######################################################
  # Termina el bloque borrable
  ########################################################################
    

  if resultado>=0:  # N1: ganador, N2:perdedor
    N1=name_local
    N2=name_visitante
  else:
    N1=name_visitante
    N2=name_local
  if resultado==0:
    r=0.5
  else:
    r=1


  Ra=Puntos.loc[N1]
  Rb=Puntos.loc[N2]

  Ves_a=1/(1+10**((Rb-Ra)/400))   # Ves: valor esperado
  Ves_b=1/(1+10**((Ra-Rb)/400))

  Vob_a=r
  Vob_b=1-r

  Sa=32*(Vob_a-Ves_a)
  Sb=32*(Vob_b-Ves_b)

  Puntos.loc[N1]+=Sa
  Puntos.loc[N2]+=Sb

a_acierta=np.array(aument_acierta)
a_predice=np.array(aument_predice)
gana_apuesta=np.array(gana_apuesta)
apuestas=np.array(aument_apuesta)
#no_partido=np.array(no_partido)
#media_movil=np.array(media_movil)

acierta_acumulado=np.add.accumulate(a_acierta)
gana_apuesta_acumulado=np.add.accumulate(gana_apuesta)
predice_acumulado=np.add.accumulate(a_predice)
apuestas_acumuladas=np.add.accumulate(apuestas)

plt.plot(no_partido, media_movil, no_partido, EM_min*np.ones(len(no_partido)))
plt.title(str(Aa.Date.unique()[[0,-1]]))

if len(apuestas_acumuladas)>0:
  print('Apuestas acertadas: ', gana_apuesta_acumulado[-1])
  print('Apuestas hechas: ', apuestas_acumuladas[-1])
  promedio=gana_apuesta_acumulado[-1]/apuestas_acumuladas[-1]
  print('Promedio de apuestas ganadas: ', promedio)
  print('momio medio: ', np.mean(momios_guardados))
  print('Esperanza matemática: ', np.mean(momios_guardados)*promedio-1)
  print('Valor inicial de la cuenta: ', Cuenta_init)
  print('Monto por apuesta: ', Monto_por_apuesta)
  print('Valor final de la cuenta: ', Cuenta)
else:
  print('No se realizaron apuestas')
# Out:
# Apuestas acertadas:  6
# Apuestas hechas:  15
# Promedio de apuestas ganadas:  0.4
# momio medio:  2.6816666666666666
# Esperanza matemática:  0.07266666666666666
# Valor inicial de la cuenta:  250
# Monto por apuesta:  25.0
# Valor final de la cuenta:  277.25

# %%
media_movil[-3:]
# Out:
# [0.5555555555555556, 0.5555555555555556, 0.5555555555555556]

# %%
a_acierta[-n_media_movil:]
# Out:
# array([False, False,  True, False,  True,  True,  True,  True, False,
#         True,  True,  True,  True, False, False,  True,  True, False,
#         True,  True, False,  True, False, False,  True, False,  True,
#        False,  True, False, False,  True, False, False,  True, False,
#         True,  True,  True, False])

# %%
 np.array([True,  True, False,
       False, False,  True, False, False,  True,  True, False, False,
        True, False,  True, False,  True,  True,  True,  True,  True,
       False,  True,  True, False,  True,  True,  True, False, False, False, True, True, True, False, True]).mean()
# Out:
# 0.5833333333333334

# %%
Puntos.T[['Twente','Sparta Rotterdam']]
# Out:
#              Twente  Sparta Rotterdam
# puntos  1136.233091        912.304914

# %%
plt.plot(predice_acumulado,acierta_acumulado/predice_acumulado)

# %%
plt.plot(no_partido, acierta_acumulado/predice_acumulado)

# %%
Puntos
# Out:
#                        puntos
# Go Ahead Eagles    985.631023
# Waalwijk           943.110353
# Heracles           947.603810
# For Sittard        914.580489
# Ajax              1190.546823
# Cambuur            913.712651
# Utrecht            994.634594
# Zwolle             921.005470
# Willem II          856.675340
# Nijmegen           959.370425
# Heerenveen         953.004036
# PSV Eindhoven     1163.146997
# Sparta Rotterdam   912.304914
# Groningen          990.419491
# Twente            1136.233091
# Feyenoord         1107.383171
# Vitesse           1017.140944
# AZ Alkmaar        1093.496377

# %% [markdown]
# Si gana Napoli a Roma entonces apostar por Atalanta
#
# Gana granada, atletico de madrid y atletic de bilbao. Si acierta dos, apostar por real madrid
